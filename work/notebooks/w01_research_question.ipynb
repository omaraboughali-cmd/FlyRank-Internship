# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
import os, sys, subprocess

# Ensure we are working in the root of the repository
# This handles both Colab and local environments
if "google.colab" in sys.modules:
    REPO_DIR = "flyrank-ml-internship-starter"
    if not os.path.exists(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/flyrank-bih/flyrank-ml-internship-starter", REPO_DIR], check=True)
    os.chdir(REPO_DIR)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("../..")
elif os.path.basename(os.getcwd()) == "work":
    os.chdir("..")

# Final check
data_path = "data/raw/content_refresh_anonymized.csv"
assert os.path.exists(data_path), f"File not found at {os.getcwd()}/{data_path}. Are you in the right directory?"
print("Success! Data found at:", os.getcwd())

import pandas as pd
df = pd.read_csv(data_path)
print("Data loaded successfully. Ready to work.")
# Out:
# Success! Data found at: /content/flyrank-ml-internship-starter
# Data loaded successfully. Ready to work.

# %%
# Lane: Content Quality & Prioritization (Freestyle)
# I am choosing to focus on identifying "declining" high-value content. I chose this lane because my Week 1 analysis revealed a clear decoupling between search volume and engagement, suggesting that a significant portion of our traffic is coming from "leaky bucket" content that needs optimization to be sustainable.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which pages should the editorial team prioritize for a content refresh this week?
# Action: The team uses the model’s ranked "Refresh Queue" to update the bottom-performing 50 pages.
# Cost of a wrong call: A false positive (flagging a healthy page) results in wasted editorial hours and unnecessary edits. A false negative (missing a declining page) results in a loss of valuable organic search traffic that could have been preserved.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show traffic volume difference
median_impressions = df.groupby("content_type")["impressions_90d"].median()
print(f"Median Impressions:\n{median_impressions}")

# Show decline rate
decline_rate = df["trend_direction"].value_counts(normalize=True)["down"]
print(f"\nOverall percentage of declining pages: {decline_rate:.2%}")
# Out:
# Median Impressions:
# content_type
# comparison article    107.0
# feedly article          4.0
# keyword article       955.0
# Name: impressions_90d, dtype: float64
#
# Overall percentage of declining pages: 54.21%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# My work provides a decision-support tool to help prioritize editorial resources. I am observing patterns in historical traffic and engagement data to suggest which pages might benefit from an update. I do not claim to predict Google’s algorithm or guarantee traffic growth. Any conclusions are directional and based on historical performance, not causal proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
